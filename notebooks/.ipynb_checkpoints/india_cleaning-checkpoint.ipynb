# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("../data/india_match_results.csv")
df.head()
# Out:
#    Test Number        Date                      Series  \
# 0            1  25/06/1932       1932 England v. India
# 1            2  15/12/1933  1933-1934 India v. England
# 2            3  05/01/1934  1933-1934 India v. England
# 3            4  10/02/1934  1933-1934 India v. England
# 4            5  27/06/1936       1936 England v. India
#
#                    Ground                    Result
# 0                  Lord's   England won by 158 runs
# 1         Gymkhana Ground  England won by 9 wickets
# 2            Eden Gardens               Match Drawn
# 3  MA Chidambaram Stadium   England won by 202 runs
# 4                  Lord's  England won by 9 wickets

# %%
df['Date'] = df['Date'].astype(str).str[-4:]

# %%
df.head()
# Out:
#    Test Number  Date                      Series                  Ground  \
# 0            1  1932       1932 England v. India                  Lord's
# 1            2  1933  1933-1934 India v. England         Gymkhana Ground
# 2            3  1934  1933-1934 India v. England            Eden Gardens
# 3            4  1934  1933-1934 India v. England  MA Chidambaram Stadium
# 4            5  1936       1936 England v. India                  Lord's
#
#                      Result
# 0   England won by 158 runs
# 1  England won by 9 wickets
# 2               Match Drawn
# 3   England won by 202 runs
# 4  England won by 9 wickets

# %%
#Replace one or more digits from the series column to just get the teams playing
#https://medium.com/@rgr5882/100-days-of-data-science-day-39-removing-unwanted-characters-from-text-columns-5b226a1f2fce#:~:text=The%20regex%20pattern%20%5B%5Ea%2D,removing%20them%20from%20the%20text.
df['Series'] = df['Series'].str.replace(r'[^a-zA-Z\s]', '', regex = True)
df.head()
# Out:
#    Test Number  Date            Series                  Ground  \
# 0            1  1932   England v India                  Lord's
# 1            2  1933   India v England         Gymkhana Ground
# 2            3  1934   India v England            Eden Gardens
# 3            4  1934   India v England  MA Chidambaram Stadium
# 4            5  1936   England v India                  Lord's
#
#                      Result
# 0   England won by 158 runs
# 1  England won by 9 wickets
# 2               Match Drawn
# 3   England won by 202 runs
# 4  England won by 9 wickets

# %%
df['Home Team'] = df['Series'].str.split().str[0]
df.head()
# Out:
#    Test Number  Date            Series                  Ground  \
# 0            1  1932   England v India                  Lord's
# 1            2  1933   India v England         Gymkhana Ground
# 2            3  1934   India v England            Eden Gardens
# 3            4  1934   India v England  MA Chidambaram Stadium
# 4            5  1936   England v India                  Lord's
#
#                      Result Home Team
# 0   England won by 158 runs   England
# 1  England won by 9 wickets     India
# 2               Match Drawn     India
# 3   England won by 202 runs     India
# 4  England won by 9 wickets   England

# %%
df['Result'] = df['Result'].str.split().str[:2].str.join(' ')

# %%
df['Winner'] = df['Result'].str.split().str[:1].str.join(' ')

# %%
df.head()
# Out:
#    Test Number  Date            Series                  Ground       Result  \
# 0            1  1932   England v India                  Lord's  England won
# 1            2  1933   India v England         Gymkhana Ground  England won
# 2            3  1934   India v England            Eden Gardens  Match Drawn
# 3            4  1934   India v England  MA Chidambaram Stadium  England won
# 4            5  1936   England v India                  Lord's  England won
#
#   Home Team   Winner
# 0   England  England
# 1     India  England
# 2     India    Match
# 3     India  England
# 4   England  England

# %%
df['Winner'] = df['Winner'].str.replace('Match', 'Draw', regex = False)
df.head()
# Out:
#    Test Number  Date            Series                  Ground       Result  \
# 0            1  1932   England v India                  Lord's  England won
# 1            2  1933   India v England         Gymkhana Ground  England won
# 2            3  1934   India v England            Eden Gardens  Match Drawn
# 3            4  1934   India v England  MA Chidambaram Stadium  England won
# 4            5  1936   England v India                  Lord's  England won
#
#   Home Team   Winner
# 0   England  England
# 1     India  England
# 2     India     Draw
# 3     India  England
# 4   England  England

# %%
df = df.drop('Result', axis = 1)
df.head()
# Out:
#    Test Number  Date            Series                  Ground Home Team  \
# 0            1  1932   England v India                  Lord's   England
# 1            2  1933   India v England         Gymkhana Ground     India
# 2            3  1934   India v England            Eden Gardens     India
# 3            4  1934   India v England  MA Chidambaram Stadium     India
# 4            5  1936   England v India                  Lord's   England
#
#     Winner
# 0  England
# 1  England
# 2     Draw
# 3  England
# 4  England

# %%
df = df.drop('Test Number', axis = 1)
df.head()
# Out:
#    Date            Series                  Ground Home Team   Winner
# 0  1932   England v India                  Lord's   England  England
# 1  1933   India v England         Gymkhana Ground     India  England
# 2  1934   India v England            Eden Gardens     India     Draw
# 3  1934   India v England  MA Chidambaram Stadium     India  England
# 4  1936   England v India                  Lord's   England  England

# %%
df = df.drop('Series', axis = 1)

# %%
df.head()
# Out:
#    Date                  Ground Home Team   Winner
# 0  1932                  Lord's   England  England
# 1  1933         Gymkhana Ground     India  England
# 2  1934            Eden Gardens     India     Draw
# 3  1934  MA Chidambaram Stadium     India  England
# 4  1936                  Lord's   England  England

# %%
df = df[df['Home Team'] == 'India']

# %%
df.head()
# Out:
#     Date                  Ground Home Team   Winner
# 1   1933         Gymkhana Ground     India  England
# 2   1934            Eden Gardens     India     Draw
# 3   1934  MA Chidambaram Stadium     India  England
# 15  1948    Arun Jaitley Stadium     India     Draw
# 16  1948       Brabourne Stadium     India     Draw

# %%
df.to_csv('../data/clean_india_data.csv', index=False)
